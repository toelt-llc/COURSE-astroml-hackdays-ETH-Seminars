# %% [markdown]
# # How to use Pre-trained models with `tk.keras.applications`
#
# (C) 2019 Umberto Michelucci
#
# umberto.michelucci@toelt.ai

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

import PIL.Image as Image

# %%
model = VGG16(weights='imagenet')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...
# 553467904/553467096 [==============================] - 12s 0us/step

# %%
IMAGE_SHAPE = (224, 224)

img = tf.keras.utils.get_file('image.jpg','http://toelt.ai/wp-content/uploads/2019/10/elephant.jpg')
img = Image.open(img).resize(IMAGE_SHAPE)
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0222630080>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
print(x.shape)
x = preprocess_input(x)
# Out:
# (1, 224, 224, 3)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# Predicted: [('n02504013', 'Indian_elephant', 0.72782034), ('n02504458', 'African_elephant', 0.14308307), ('n01871265', 'tusker', 0.12798563)]
